# %%
import nhl 
import requests
import pandas as pd
from sqlalchemy import create_engine
from credentials import HOCKEY_DB_NAME, HOCKEY_DB_PWD
from datetime import date, timedelta
from pytz import timezone

from schedule import parse_schedule, get_schedule
from play import Shot, Goal, Penalty, Faceoff, Other, process_game, process_play_bundle
from boxscore import process_player_boxscore, process_team_boxscore

# %%
BASE = "http://statsapi.web.nhl.com/api/v1"

# %% [markdown]
# ### Schedule

# %%
engine = create_engine('postgresql://baseball:{}@localhost:5432/{}'.format(HOCKEY_DB_PWD, HOCKEY_DB_NAME))

res = engine.execute("DROP TABLE IF EXISTS nhl_schedule")
res.close()

# %%
schedule = get_schedule(startdate = '2019-01-01', enddate = date.today() - timedelta(days = 1))

# %%
schedule = schedule[schedule['game_type'] == 'R']

# %%
schedule['game_date'] = pd.to_datetime(schedule['game_date'])
schedule['game_date'] = schedule['game_date'].apply(lambda x: x.astimezone(timezone('US/Eastern')))
schedule['game_date'] = schedule['game_date'].apply(lambda x: x.tz_localize(None))

# %%
schedule.to_sql('nhl_schedule', con = engine, index = False, if_exists = 'append')
# Out:
# 350

# %% [markdown]
# ### Boxscores

# %%
#game_pks = pd.read_sql("""SELECT DISTINCT s.game_pk FROM nhl_schedule s LEFT JOIN nhl_team_boxscore b ON s.game_pk = b.game_pk;""", engine)

# %%
#res = engine.execute("DROP TABLE IF EXISTS nhl_team_boxscore")
#res.close()

#res = engine.execute("DROP TABLE IF EXISTS nhl_player_boxscore")
#res.close()

# %%
game_pks = pd.read_sql("""SELECT DISTINCT s.game_pk FROM nhl_schedule s LEFT JOIN nhl_team_boxscore b ON s.game_pk = b.game_pk WHERE b.game_pk IS NULL;""", engine)

# %%
n_games = game_pks.shape[0]

n_games
# Out:
# 7

# %%
for i, g in enumerate(game_pks['game_pk'].values):
    s = requests.get('{}/game/{}/boxscore'.format(BASE, g)).json()
    
    try:
        team = process_team_boxscore(s['teams'])
        team['game_pk'] = g
        team.to_sql('nhl_team_boxscore', engine, index = False, if_exists = 'append')
        
        away_players = pd.concat([process_player_boxscore(p) for p in s['teams']['away']['players'].values()]).reset_index()
        away_players['team'] = team['away_team'].iloc[0]
        away_players['opposing_team'] = team['home_team'].iloc[0]
 
        
        home_players = pd.concat([process_player_boxscore(p) for p in s['teams']['home']['players'].values()]).reset_index()
        home_players['team'] = team['home_team'].iloc[0]
        home_players['opposing_team'] = team['away_team'].iloc[0]
        
        away_players['opposing_goalie'] = home_players.query('is_goalie == True').sort_values('timeOnIce', ascending=False).iloc[0]['player_name']
        home_players['opposing_goalie'] = away_players.query('is_goalie == True').sort_values('timeOnIce', ascending=False).iloc[0]['player_name']
        
        players = pd.concat([away_players, home_players]).reset_index()
        players['game_pk'] = g
        players = players[~(pd.isnull(players['timeOnIce']))]
        players['time_on_ice'] = players['timeOnIce'].apply(lambda x: int(x.split(':')[0]) * 60 + int(x.split(':')[1]))
        players = players.query('time_on_ice > 300')
        
        del players['timeOnIce']
        del players['level_0']
        del players['index']
        
        players.to_sql('nhl_player_boxscore', engine, index = False, if_exists = 'append')
    except:
        pass
    
    if i % 20 == 0:
        print(i / n_games)
# Out:
# 0.0

# %%
g = requests.get('{}/game/{}/boxscore'.format(BASE, g)).json()

# %%
g
# Out:
# {'copyright': 'NHL and the NHL Shield are registered trademarks of the National Hockey League. NHL and NHL team marks are the property of the NHL and its teams. © NHL 2022. All Rights Reserved.',
#  'teams': {'away': {'team': {'id': 3,
#     'name': 'New York Rangers',
#     'link': '/api/v1/teams/3'},
#    'teamStats': {'teamSkaterStats': {'goals': 5,
#      'pim': 13,
#      'shots': 37,
#      'powerPlayPercentage': '40.0',
#      'powerPlayGoals': 2.0,
#      'powerPlayOpportunities': 5.0,
#      'faceOffWinPercentage': '45.9',
#      'blocked': 26,
#      'takeaways': 6,
#      'giveaways': 9,
#      'hits': 32}},
#    'players': {'ID8482073': {'person': {'id': 8482073,
#       'fullName': 'Braden Schneider',
#       'link': '/api/v1/people/8482073',
#       'firstName': 'Braden',
#       'lastName': 'Schneider',
#       'primaryNumber': '4',
#       'birthDate': '2001-09-20',
#       'currentAge': 21,
#       'birthCity': 'Prince Albert',
#       'birthStateProvince': 'SK',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 3"',
#       'weight': 208,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '4',
#      'position': {'code': 'D',
#       'name': 'Defenseman',
#       'type': 'Defenseman',
#       'abbreviation': 'D'},
#      'stats': {'skaterStats': {'timeOnIce': '16:34',
#        'assists': 0,
#        'goals': 0,
#        'shots': 0,
#        'hits': 0,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 1,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 1,
#        'plusMinus': 1,
#        'evenTimeOnIce': '15:33',
#        'powerPlayTimeOnIce': '0:01',
#        'shortHandedTimeOnIce': '1:00'}}},
#     'ID8476918': {'person': {'id': 8476918,
#       'fullName': 'Jimmy Vesey',
#       'link': '/api/v1/people/8476918',
#       'firstName': 'Jimmy',
#       'lastName': 'Vesey',
#       'primaryNumber': '26',
#       'birthDate': '1993-05-26',
#       'currentAge': 29,
#       'birthCity': 'Boston',
#       'birthStateProvince': 'MA',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '6\' 3"',
#       'weight': 202,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'L',
#        'name': 'Left Wing',
#        'type': 'Forward',
#        'abbreviation': 'LW'}},
#      'jerseyNumber': '26',
#      'position': {'code': 'L',
#       'name': 'Left Wing',
#       'type': 'Forward',
#       'abbreviation': 'LW'},
#      'stats': {'skaterStats': {'timeOnIce': '13:23',
#        'assists': 0,
#        'goals': 0,
#        'shots': 0,
#        'hits': 2,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 1,
#        'plusMinus': 0,
#        'evenTimeOnIce': '12:19',
#        'powerPlayTimeOnIce': '0:00',
#        'shortHandedTimeOnIce': '1:04'}}},
#     'ID8479328': {'person': {'id': 8479328,
#       'fullName': 'Julien Gauthier',
#       'link': '/api/v1/people/8479328',
#       'firstName': 'Julien',
#       'lastName': 'Gauthier',
#       'primaryNumber': '12',
#       'birthDate': '1997-10-15',
#       'currentAge': 25,
#       'birthCity': 'Pointe-aux-Trembles',
#       'birthStateProvince': 'QC',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 4"',
#       'weight': 224,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'R',
#        'name': 'Right Wing',
#        'type': 'Forward',
#        'abbreviation': 'RW'}},
#      'jerseyNumber': '12',
#      'position': {'code': 'R',
#       'name': 'Right Wing',
#       'type': 'Forward',
#       'abbreviation': 'RW'},
#      'stats': {'skaterStats': {'timeOnIce': '9:58',
#        'assists': 0,
#        'goals': 0,
#        'shots': 2,
#        'hits': 3,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 2,
#        'plusMinus': 0,
#        'evenTimeOnIce': '9:58',
#        'powerPlayTimeOnIce': '0:00',
#        'shortHandedTimeOnIce': '0:00'}}},
#     'ID8476624': {'person': {'id': 8476624,
#       'fullName': 'Barclay Goodrow',
#       'link': '/api/v1/people/8476624',
#       'firstName': 'Barclay',
#       'lastName': 'Goodrow',
#       'primaryNumber': '21',
#       'birthDate': '1993-02-26',
#       'currentAge': 29,
#       'birthCity': 'Toronto',
#       'birthStateProvince': 'ON',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 2"',
#       'weight': 204,
#       'active': True,
#       'alternateCaptain': True,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '21',
#      'position': {'code': 'C',
#       'name': 'Center',
#       'type': 'Forward',
#       'abbreviation': 'C'},
#      'stats': {'skaterStats': {'timeOnIce': '13:10',
#        'assists': 1,
#        'goals': 0,
#        'shots': 0,
#        'hits': 5,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 7,
#        'faceOffPct': 28.57,
#        'faceOffWins': 2,
#        'faceoffTaken': 7,
#        'takeaways': 0,
#        'giveaways': 2,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 2,
#        'plusMinus': 1,
#        'evenTimeOnIce': '12:10',
#        'powerPlayTimeOnIce': '0:00',
#        'shortHandedTimeOnIce': '1:00'}}},
#     'ID8476459': {'person': {'id': 8476459,
#       'fullName': 'Mika Zibanejad',
#       'link': '/api/v1/people/8476459',
#       'firstName': 'Mika',
#       'lastName': 'Zibanejad',
#       'primaryNumber': '93',
#       'birthDate': '1993-04-18',
#       'currentAge': 29,
#       'birthCity': 'Stockholm',
#       'birthCountry': 'SWE',
#       'nationality': 'SWE',
#       'height': '6\' 2"',
#       'weight': 202,
#       'active': True,
#       'alternateCaptain': True,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '93',
#      'position': {'code': 'C',
#       'name': 'Center',
#       'type': 'Forward',
#       'abbreviation': 'C'},
#      'stats': {'skaterStats': {'timeOnIce': '20:43',
#        'assists': 1,
#        'goals': 2,
#        'shots': 4,
#        'hits': 1,
#        'powerPlayGoals': 2,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffPct': 33.33,
#        'faceOffWins': 5,
#        'faceoffTaken': 15,
#        'takeaways': 1,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 1,
#        'plusMinus': 2,
#        'evenTimeOnIce': '13:39',
#        'powerPlayTimeOnIce': '5:15',
#        'shortHandedTimeOnIce': '1:49'}}},
#     'ID8477846': {'person': {'id': 8477846,
#       'fullName': 'Ryan Carpenter',
#       'link': '/api/v1/people/8477846',
#       'firstName': 'Ryan',
#       'lastName': 'Carpenter',
#       'primaryNumber': '22',
#       'birthDate': '1991-01-18',
#       'currentAge': 31,
#       'birthCity': 'Oviedo',
#       'birthStateProvince': 'FL',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '6\' 1"',
#       'weight': 198,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '22',
#      'position': {'code': 'N/A',
#       'name': 'Unknown',
#       'type': 'Unknown',
#       'abbreviation': 'N/A'},
#      'stats': {}},
#     'ID8482109': {'person': {'id': 8482109,
#       'fullName': 'Alexis Lafrenière',
#       'link': '/api/v1/people/8482109',
#       'firstName': 'Alexis',
#       'lastName': 'Lafrenière',
#       'primaryNumber': '13',
#       'birthDate': '2001-10-11',
#       'currentAge': 21,
#       'birthCity': 'St-Eustache',
#       'birthStateProvince': 'QC',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 1"',
#       'weight': 195,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'L',
#        'name': 'Left Wing',
#        'type': 'Forward',
#        'abbreviation': 'LW'}},
#      'jerseyNumber': '13',
#      'position': {'code': 'L',
#       'name': 'Left Wing',
#       'type': 'Forward',
#       'abbreviation': 'LW'},
#      'stats': {'skaterStats': {'timeOnIce': '13:53',
#        'assists': 0,
#        'goals': 1,
#        'shots': 2,
#        'hits': 0,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 2,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': 2,
#        'evenTimeOnIce': '12:05',
#        'powerPlayTimeOnIce': '1:48',
#        'shortHandedTimeOnIce': '0:00'}}},
#     'ID8478104': {'person': {'id': 8478104,
#       'fullName': 'Sammy Blais',
#       'link': '/api/v1/people/8478104',
#       'firstName': 'Sammy',
#       'lastName': 'Blais',
#       'primaryNumber': '91',
#       'birthDate': '1996-06-17',
#       'currentAge': 26,
#       'birthCity': 'Montmagny',
#       'birthStateProvince': 'QC',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 2"',
#       'weight': 206,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'L',
#        'name': 'Left Wing',
#        'type': 'Forward',
#        'abbreviation': 'LW'}},
#      'jerseyNumber': '91',
#      'position': {'code': 'L',
#       'name': 'Left Wing',
#       'type': 'Forward',
#       'abbreviation': 'LW'},
#      'stats': {'skaterStats': {'timeOnIce': '12:18',
#        'assists': 0,
#        'goals': 0,
#        'shots': 2,
#        'hits': 5,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffPct': 0.0,
#        'faceOffWins': 0,
#        'faceoffTaken': 1,
#        'takeaways': 0,
#        'giveaways': 1,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': 0,
#        'evenTimeOnIce': '11:25',
#        'powerPlayTimeOnIce': '0:53',
#        'shortHandedTimeOnIce': '0:00'}}},
#     'ID8477433': {'person': {'id': 8477433,
#       'fullName': 'Ben Harpur',
#       'link': '/api/v1/people/8477433',
#       'firstName': 'Ben',
#       'lastName': 'Harpur',
#       'primaryNumber': '5',
#       'birthDate': '1995-01-12',
#       'currentAge': 27,
#       'birthCity': 'Hamilton',
#       'birthStateProvince': 'ON',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 6"',
#       'weight': 231,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '5',
#      'position': {'code': 'N/A',
#       'name': 'Unknown',
#       'type': 'Unknown',
#       'abbreviation': 'N/A'},
#      'stats': {}},
#     'ID8478048': {'person': {'id': 8478048,
#       'fullName': 'Igor Shesterkin',
#       'link': '/api/v1/people/8478048',
#       'firstName': 'Igor',
#       'lastName': 'Shesterkin',
#       'primaryNumber': '31',
#       'birthDate': '1995-12-30',
#       'currentAge': 26,
#       'birthCity': 'Moscow',
#       'birthCountry': 'RUS',
#       'nationality': 'RUS',
#       'height': '6\' 1"',
#       'weight': 189,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'G',
#        'name': 'Goalie',
#        'type': 'Goalie',
#        'abbreviation': 'G'}},
#      'jerseyNumber': '31',
#      'position': {'code': 'G',
#       'name': 'Goalie',
#       'type': 'Goalie',
#       'abbreviation': 'G'},
#      'stats': {'goalieStats': {'timeOnIce': '59:14',
#        'assists': 0,
#        'goals': 0,
#        'pim': 0,
#        'shots': 26,
#        'saves': 25,
#        'powerPlaySaves': 8,
#        'shortHandedSaves': 0,
#        'evenSaves': 17,
#        'shortHandedShotsAgainst': 0,
#        'evenShotsAgainst': 17,
#        'powerPlayShotsAgainst': 9,
#        'decision': 'W',
#        'savePercentage': 96.15384615384616,
#        'powerPlaySavePercentage': 88.88888888888889,
#        'evenStrengthSavePercentage': 100.0}}},
#     'ID8480833': {'person': {'id': 8480833,
#       'fullName': 'Vitali Kravtsov',
#       'link': '/api/v1/people/8480833',
#       'firstName': 'Vitali',
#       'lastName': 'Kravtsov',
#       'primaryNumber': '74',
#       'birthDate': '1999-12-23',
#       'currentAge': 22,
#       'birthCity': 'Vladivostok',
#       'birthCountry': 'RUS',
#       'nationality': 'RUS',
#       'height': '6\' 3"',
#       'weight': 186,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': True,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'R',
#        'name': 'Right Wing',
#        'type': 'Forward',
#        'abbreviation': 'RW'}},
#      'jerseyNumber': '74',
#      'position': {'code': 'N/A',
#       'name': 'Unknown',
#       'type': 'Unknown',
#       'abbreviation': 'N/A'},
#      'stats': {}},
#     'ID8476389': {'person': {'id': 8476389,
#       'fullName': 'Vincent Trocheck',
#       'link': '/api/v1/people/8476389',
#       'firstName': 'Vincent',
#       'lastName': 'Trocheck',
#       'primaryNumber': '16',
#       'birthDate': '1993-07-11',
#       'currentAge': 29,
#       'birthCity': 'Pittsburgh',
#       'birthStateProvince': 'PA',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '5\' 11"',
#       'weight': 184,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '16',
#      'position': {'code': 'C',
#       'name': 'Center',
#       'type': 'Forward',
#       'abbreviation': 'C'},
#      'stats': {'skaterStats': {'timeOnIce': '18:10',
#        'assists': 1,
#        'goals': 0,
#        'shots': 4,
#        'hits': 2,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 1,
#        'penaltyMinutes': 2,
#        'faceOffPct': 56.25,
#        'faceOffWins': 9,
#        'faceoffTaken': 16,
#        'takeaways': 1,
#        'giveaways': 1,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 1,
#        'plusMinus': 0,
#        'evenTimeOnIce': '13:05',
#        'powerPlayTimeOnIce': '5:05',
#        'shortHandedTimeOnIce': '0:00'}}},
#     'ID8479324': {'person': {'id': 8479324,
#       'fullName': 'Ryan Lindgren',
#       'link': '/api/v1/people/8479324',
#       'firstName': 'Ryan',
#       'lastName': 'Lindgren',
#       'primaryNumber': '55',
#       'birthDate': '1998-02-11',
#       'currentAge': 24,
#       'birthCity': 'Burnsville',
#       'birthStateProvince': 'MN',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '6\' 0"',
#       'weight': 190,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '55',
#      'position': {'code': 'D',
#       'name': 'Defenseman',
#       'type': 'Defenseman',
#       'abbreviation': 'D'},
#      'stats': {'skaterStats': {'timeOnIce': '17:25',
#        'assists': 0,
#        'goals': 0,
#        'shots': 2,
#        'hits': 2,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 2,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 3,
#        'plusMinus': 2,
#        'evenTimeOnIce': '16:17',
#        'powerPlayTimeOnIce': '0:33',
#        'shortHandedTimeOnIce': '0:35'}}},
#     'ID8476885': {'person': {'id': 8476885,
#       'fullName': 'Jacob Trouba',
#       'link': '/api/v1/people/8476885',
#       'firstName': 'Jacob',
#       'lastName': 'Trouba',
#       'primaryNumber': '8',
#       'birthDate': '1994-02-26',
#       'currentAge': 28,
#       'birthCity': 'Rochester',
#       'birthStateProvince': 'MI',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '6\' 3"',
#       'weight': 203,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': True,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '8',
#      'position': {'code': 'D',
#       'name': 'Defenseman',
#       'type': 'Defenseman',
#       'abbreviation': 'D'},
#      'stats': {'skaterStats': {'timeOnIce': '21:54',
#        'assists': 1,
#        'goals': 0,
#        'shots': 4,
#        'hits': 5,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 2,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 1,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 3,
#        'plusMinus': 1,
#        'evenTimeOnIce': '18:13',
#        'powerPlayTimeOnIce': '2:26',
#        'shortHandedTimeOnIce': '1:15'}}},
#     'ID8475184': {'person': {'id': 8475184,
#       'fullName': 'Chris Kreider',
#       'link': '/api/v1/people/8475184',
#       'firstName': 'Chris',
#       'lastName': 'Kreider',
#       'primaryNumber': '20',
#       'birthDate': '1991-04-30',
#       'currentAge': 31,
#       'birthCity': 'Boxford',
#       'birthStateProvince': 'MA',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '6\' 3"',
#       'weight': 230,
#       'active': True,
#       'alternateCaptain': True,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'L',
#        'name': 'Left Wing',
#        'type': 'Forward',
#        'abbreviation': 'LW'}},
#      'jerseyNumber': '20',
#      'position': {'code': 'L',
#       'name': 'Left Wing',
#       'type': 'Forward',
#       'abbreviation': 'LW'},
#      'stats': {'skaterStats': {'timeOnIce': '17:34',
#        'assists': 0,
#        'goals': 0,
#        'shots': 2,
#        'hits': 1,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 2,
#        'plusMinus': 0,
#        'evenTimeOnIce': '11:08',
#        'powerPlayTimeOnIce': '5:07',
#        'shortHandedTimeOnIce': '1:19'}}},
#     'ID8479333': {'person': {'id': 8479333,
#       'fullName': 'Libor Hajek',
#       'link': '/api/v1/people/8479333',
#       'firstName': 'Libor',
#       'lastName': 'Hajek',
#       'primaryNumber': '25',
#       'birthDate': '1998-02-04',
#       'currentAge': 24,
#       'birthCity': 'Smrcek',
#       'birthCountry': 'CZE',
#       'nationality': 'CZE',
#       'height': '6\' 2"',
#       'weight': 209,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '25',
#      'position': {'code': 'D',
#       'name': 'Defenseman',
#       'type': 'Defenseman',
#       'abbreviation': 'D'},
#      'stats': {'skaterStats': {'timeOnIce': '13:47',
#        'assists': 0,
#        'goals': 0,
#        'shots': 0,
#        'hits': 1,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 3,
#        'plusMinus': 0,
#        'evenTimeOnIce': '13:47',
#        'powerPlayTimeOnIce': '0:00',
#        'shortHandedTimeOnIce': '0:00'}}},
#     'ID8478550': {'person': {'id': 8478550,
#       'fullName': 'Artemi Panarin',
#       'link': '/api/v1/people/8478550',
#       'firstName': 'Artemi',
#       'lastName': 'Panarin',
#       'primaryNumber': '10',
#       'birthDate': '1991-10-30',
#       'currentAge': 31,
#       'birthCity': 'Korkino',
#       'birthCountry': 'RUS',
#       'nationality': 'RUS',
#       'height': '6\' 0"',
#       'weight': 173,
#       'active': True,
#       'alternateCaptain': True,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'L',
#        'name': 'Left Wing',
#        'type': 'Forward',
#        'abbreviation': 'LW'}},
#      'jerseyNumber': '10',
#      'position': {'code': 'L',
#       'name': 'Left Wing',
#       'type': 'Forward',
#       'abbreviation': 'LW'},
#      'stats': {'skaterStats': {'timeOnIce': '20:39',
#        'assists': 3,
#        'goals': 0,
#        'shots': 6,
#        'hits': 0,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 2,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 1,
#        'plusMinus': 1,
#        'evenTimeOnIce': '15:39',
#        'powerPlayTimeOnIce': '5:00',
#        'shortHandedTimeOnIce': '0:00'}}},
#     'ID8479323': {'person': {'id': 8479323,
#       'fullName': 'Adam Fox',
#       'link': '/api/v1/people/8479323',
#       'firstName': 'Adam',
#       'lastName': 'Fox',
#       'primaryNumber': '23',
#       'birthDate': '1998-02-17',
#       'currentAge': 24,
#       'birthCity': 'Jericho',
#       'birthStateProvince': 'NY',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '5\' 11"',
#       'weight': 182,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '23',
#      'position': {'code': 'D',
#       'name': 'Defenseman',
#       'type': 'Defenseman',
#       'abbreviation': 'D'},
#      'stats': {'skaterStats': {'timeOnIce': '22:43',
#        'assists': 2,
#        'goals': 0,
#        'shots': 3,
#        'hits': 0,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 1,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 2,
#        'giveaways': 1,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 3,
#        'plusMinus': 1,
#        'evenTimeOnIce': '16:22',
#        'powerPlayTimeOnIce': '4:31',
#        'shortHandedTimeOnIce': '1:50'}}},
#     'ID8480817': {'person': {'id': 8480817,
#       'fullName': "K'Andre Miller",
#       'link': '/api/v1/people/8480817',
#       'firstName': "K'Andre",
#       'lastName': 'Miller',
#       'primaryNumber': '79',
#       'birthDate': '2000-01-21',
#       'currentAge': 22,
#       'birthCity': 'St. Paul',
#       'birthStateProvince': 'MN',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '6\' 5"',
#       'weight': 215,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '79',
#      'position': {'code': 'D',
#       'name': 'Defenseman',
#       'type': 'Defenseman',
#       'abbreviation': 'D'},
#      'stats': {'skaterStats': {'timeOnIce': '22:11',
#        'assists': 1,
#        'goals': 0,
#        'shots': 0,
#        'hits': 2,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 2,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 2,
#        'plusMinus': 1,
#        'evenTimeOnIce': '20:24',
#        'powerPlayTimeOnIce': '0:47',
#        'shortHandedTimeOnIce': '1:00'}}},
#     'ID8477380': {'person': {'id': 8477380,
#       'fullName': 'Jonny Brodzinski',
#       'link': '/api/v1/people/8477380',
#       'firstName': 'Jonny',
#       'lastName': 'Brodzinski',
#       'primaryNumber': '76',
#       'birthDate': '1993-06-19',
#       'currentAge': 29,
#       'birthCity': 'Ham Lake',
#       'birthStateProvince': 'MN',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '6\' 0"',
#       'weight': 212,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '76',
#      'position': {'code': 'C',
#       'name': 'Center',
#       'type': 'Forward',
#       'abbreviation': 'C'},
#      'stats': {'skaterStats': {'timeOnIce': '9:12',
#        'assists': 0,
#        'goals': 0,
#        'shots': 2,
#        'hits': 2,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffPct': 66.67,
#        'faceOffWins': 8,
#        'faceoffTaken': 12,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': 0,
#        'evenTimeOnIce': '9:12',
#        'powerPlayTimeOnIce': '0:00',
#        'shortHandedTimeOnIce': '0:00'}}},
#     'ID8480078': {'person': {'id': 8480078,
#       'fullName': 'Filip Chytil',
#       'link': '/api/v1/people/8480078',
#       'firstName': 'Filip',
#       'lastName': 'Chytil',
#       'primaryNumber': '72',
#       'birthDate': '1999-09-05',
#       'currentAge': 23,
#       'birthCity': 'Kromeriz',
#       'birthCountry': 'CZE',
#       'nationality': 'CZE',
#       'height': '6\' 2"',
#       'weight': 204,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '72',
#      'position': {'code': 'C',
#       'name': 'Center',
#       'type': 'Forward',
#       'abbreviation': 'C'},
#      'stats': {'skaterStats': {'timeOnIce': '16:08',
#        'assists': 0,
#        'goals': 1,
#        'shots': 3,
#        'hits': 1,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffPct': 40.0,
#        'faceOffWins': 4,
#        'faceoffTaken': 10,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 1,
#        'plusMinus': 1,
#        'evenTimeOnIce': '14:30',
#        'powerPlayTimeOnIce': '1:38',
#        'shortHandedTimeOnIce': '0:00'}}},
#     'ID8481554': {'person': {'id': 8481554,
#       'fullName': 'Kaapo Kakko',
#       'link': '/api/v1/people/8481554',
#       'firstName': 'Kaapo',
#       'lastName': 'Kakko',
#       'primaryNumber': '24',
#       'birthDate': '2001-02-13',
#       'currentAge': 21,
#       'birthCity': 'Turku',
#       'birthCountry': 'FIN',
#       'nationality': 'FIN',
#       'height': '6\' 2"',
#       'weight': 206,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 3,
#        'name': 'New York Rangers',
#        'link': '/api/v1/teams/3'},
#       'primaryPosition': {'code': 'R',
#        'name': 'Right Wing',
#        'type': 'Forward',
#        'abbreviation': 'RW'}},
#      'jerseyNumber': '24',
#      'position': {'code': 'R',
#       'name': 'Right Wing',
#       'type': 'Forward',
#       'abbreviation': 'RW'},
#      'stats': {'skaterStats': {'timeOnIce': '14:30',
#        'assists': 0,
#        'goals': 1,
#        'shots': 1,
#        'hits': 0,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': 2,
#        'evenTimeOnIce': '12:59',
#        'powerPlayTimeOnIce': '1:31',
#        'shortHandedTimeOnIce': '0:00'}}}},
#    'goalies': [8478048],
#    'skaters': [8482073,
#     8476885,
#     8478550,
#     8479328,
#     8482109,
#     8476389,
#     8475184,
#     8476624,
#     8479323,
#     8481554,
#     8479333,
#     8476918,
#     8479324,
#     8480078,
#     8477380,
#     8480817,
#     8478104,
#     8476459,
#     8477433,
#     8477846,
#     8480833],
#    'onIce': [8475184, 8476389, 8476918, 8478048, 8479324, 8480817],
#    'onIcePlus': [{'playerId': 8475184, 'shiftDuration': 66, 'stamina': 33},
#     {'playerId': 8476389, 'shiftDuration': 72, 'stamina': 33},
#     {'playerId': 8476918, 'shiftDuration': 66, 'stamina': 33},
#     {'playerId': 8478048, 'shiftDuration': 306, 'stamina': 33},
#     {'playerId': 8479324, 'shiftDuration': 54, 'stamina': 66},
#     {'playerId': 8480817, 'shiftDuration': 66, 'stamina': 33}],
#    'scratches': [8477433, 8477846, 8480833],
#    'penaltyBox': [],
#    'coaches': [{'person': {'fullName': 'Gerard Gallant',
#       'link': '/api/v1/people/null'},
#      'position': {'code': 'HC',
#       'name': 'Head Coach',
#       'type': 'Head Coach',
#       'abbreviation': 'Head Coach'}}]},
#   'home': {'team': {'id': 54,
#     'name': 'Vegas Golden Knights',
#     'link': '/api/v1/teams/54'},
#    'teamStats': {'teamSkaterStats': {'goals': 1,
#      'pim': 27,
#      'shots': 26,
#      'powerPlayPercentage': '33.3',
#      'powerPlayGoals': 1.0,
#      'powerPlayOpportunities': 3.0,
#      'faceOffWinPercentage': '54.1',
#      'blocked': 13,
#      'takeaways': 9,
#      'giveaways': 7,
#      'hits': 22}},
#    'players': {'ID8476905': {'person': {'id': 8476905,
#       'fullName': 'Chandler Stephenson',
#       'link': '/api/v1/people/8476905',
#       'firstName': 'Chandler',
#       'lastName': 'Stephenson',
#       'primaryNumber': '20',
#       'birthDate': '1994-04-22',
#       'currentAge': 28,
#       'birthCity': 'Saskatoon',
#       'birthStateProvince': 'SK',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 0"',
#       'weight': 209,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '20',
#      'position': {'code': 'C',
#       'name': 'Center',
#       'type': 'Forward',
#       'abbreviation': 'C'},
#      'stats': {'skaterStats': {'timeOnIce': '17:15',
#        'assists': 1,
#        'goals': 0,
#        'shots': 2,
#        'hits': 2,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 1,
#        'penaltyMinutes': 10,
#        'faceOffPct': 59.09,
#        'faceOffWins': 13,
#        'faceoffTaken': 22,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': -1,
#        'evenTimeOnIce': '13:17',
#        'powerPlayTimeOnIce': '2:19',
#        'shortHandedTimeOnIce': '1:39'}}},
#     'ID8481032': {'person': {'id': 8481032,
#       'fullName': 'Paul Cotter',
#       'link': '/api/v1/people/8481032',
#       'firstName': 'Paul',
#       'lastName': 'Cotter',
#       'primaryNumber': '43',
#       'birthDate': '1999-11-16',
#       'currentAge': 23,
#       'birthCity': 'Canton',
#       'birthStateProvince': 'MI',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '6\' 2"',
#       'weight': 212,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': True,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '43',
#      'position': {'code': 'C',
#       'name': 'Center',
#       'type': 'Forward',
#       'abbreviation': 'C'},
#      'stats': {'skaterStats': {'timeOnIce': '15:42',
#        'assists': 0,
#        'goals': 0,
#        'shots': 2,
#        'hits': 6,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': -1,
#        'evenTimeOnIce': '14:33',
#        'powerPlayTimeOnIce': '1:09',
#        'shortHandedTimeOnIce': '0:00'}}},
#     'ID8476539': {'person': {'id': 8476539,
#       'fullName': 'Jonathan Marchessault',
#       'link': '/api/v1/people/8476539',
#       'firstName': 'Jonathan',
#       'lastName': 'Marchessault',
#       'primaryNumber': '81',
#       'birthDate': '1990-12-27',
#       'currentAge': 31,
#       'birthCity': 'Cap-Rouge',
#       'birthStateProvince': 'QC',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '5\' 9"',
#       'weight': 183,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '81',
#      'position': {'code': 'C',
#       'name': 'Center',
#       'type': 'Forward',
#       'abbreviation': 'C'},
#      'stats': {'skaterStats': {'timeOnIce': '14:55',
#        'assists': 0,
#        'goals': 1,
#        'shots': 3,
#        'hits': 1,
#        'powerPlayGoals': 1,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffPct': 100.0,
#        'faceOffWins': 1,
#        'faceoffTaken': 1,
#        'takeaways': 1,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': 0,
#        'evenTimeOnIce': '12:25',
#        'powerPlayTimeOnIce': '2:30',
#        'shortHandedTimeOnIce': '0:00'}}},
#     'ID8475913': {'person': {'id': 8475913,
#       'fullName': 'Mark Stone',
#       'link': '/api/v1/people/8475913',
#       'firstName': 'Mark',
#       'lastName': 'Stone',
#       'primaryNumber': '61',
#       'birthDate': '1992-05-13',
#       'currentAge': 30,
#       'birthCity': 'Winnipeg',
#       'birthStateProvince': 'MB',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 3"',
#       'weight': 217,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': True,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'R',
#        'name': 'Right Wing',
#        'type': 'Forward',
#        'abbreviation': 'RW'}},
#      'jerseyNumber': '61',
#      'position': {'code': 'R',
#       'name': 'Right Wing',
#       'type': 'Forward',
#       'abbreviation': 'RW'},
#      'stats': {'skaterStats': {'timeOnIce': '15:48',
#        'assists': 0,
#        'goals': 0,
#        'shots': 1,
#        'hits': 1,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 2,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 1,
#        'giveaways': 1,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': -1,
#        'evenTimeOnIce': '13:49',
#        'powerPlayTimeOnIce': '0:50',
#        'shortHandedTimeOnIce': '1:09'}}},
#     'ID8473548': {'person': {'id': 8473548,
#       'fullName': 'Phil Kessel',
#       'link': '/api/v1/people/8473548',
#       'firstName': 'Phil',
#       'lastName': 'Kessel',
#       'primaryNumber': '8',
#       'birthDate': '1987-10-02',
#       'currentAge': 35,
#       'birthCity': 'Madison',
#       'birthStateProvince': 'WI',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '5\' 11"',
#       'weight': 208,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '8',
#      'position': {'code': 'C',
#       'name': 'Center',
#       'type': 'Forward',
#       'abbreviation': 'C'},
#      'stats': {'skaterStats': {'timeOnIce': '11:29',
#        'assists': 0,
#        'goals': 0,
#        'shots': 0,
#        'hits': 0,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffPct': 0.0,
#        'faceOffWins': 0,
#        'faceoffTaken': 1,
#        'takeaways': 1,
#        'giveaways': 1,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': -2,
#        'evenTimeOnIce': '11:07',
#        'powerPlayTimeOnIce': '0:22',
#        'shortHandedTimeOnIce': '0:00'}}},
#     'ID8477447': {'person': {'id': 8477447,
#       'fullName': 'Shea Theodore',
#       'link': '/api/v1/people/8477447',
#       'firstName': 'Shea',
#       'lastName': 'Theodore',
#       'primaryNumber': '27',
#       'birthDate': '1995-08-03',
#       'currentAge': 27,
#       'birthCity': 'Langley',
#       'birthStateProvince': 'BC',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 2"',
#       'weight': 197,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '27',
#      'position': {'code': 'D',
#       'name': 'Defenseman',
#       'type': 'Defenseman',
#       'abbreviation': 'D'},
#      'stats': {'skaterStats': {'timeOnIce': '20:35',
#        'assists': 1,
#        'goals': 0,
#        'shots': 3,
#        'hits': 0,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 1,
#        'penaltyMinutes': 4,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 1,
#        'plusMinus': -1,
#        'evenTimeOnIce': '17:47',
#        'powerPlayTimeOnIce': '2:48',
#        'shortHandedTimeOnIce': '0:00'}}},
#     'ID8477018': {'person': {'id': 8477018,
#       'fullName': 'Ben Hutton',
#       'link': '/api/v1/people/8477018',
#       'firstName': 'Ben',
#       'lastName': 'Hutton',
#       'primaryNumber': '17',
#       'birthDate': '1993-04-20',
#       'currentAge': 29,
#       'birthCity': 'Brockville',
#       'birthStateProvince': 'ON',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 3"',
#       'weight': 201,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '17',
#      'position': {'code': 'N/A',
#       'name': 'Unknown',
#       'type': 'Unknown',
#       'abbreviation': 'N/A'},
#      'stats': {}},
#     'ID8476448': {'person': {'id': 8476448,
#       'fullName': 'William Karlsson',
#       'link': '/api/v1/people/8476448',
#       'firstName': 'William',
#       'lastName': 'Karlsson',
#       'primaryNumber': '71',
#       'birthDate': '1993-01-08',
#       'currentAge': 29,
#       'birthCity': 'Marsta',
#       'birthCountry': 'SWE',
#       'nationality': 'SWE',
#       'height': '6\' 0"',
#       'weight': 190,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '71',
#      'position': {'code': 'C',
#       'name': 'Center',
#       'type': 'Forward',
#       'abbreviation': 'C'},
#      'stats': {'skaterStats': {'timeOnIce': '19:20',
#        'assists': 0,
#        'goals': 0,
#        'shots': 6,
#        'hits': 0,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffPct': 47.06,
#        'faceOffWins': 8,
#        'faceoffTaken': 17,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 1,
#        'plusMinus': -1,
#        'evenTimeOnIce': '14:53',
#        'powerPlayTimeOnIce': '0:20',
#        'shortHandedTimeOnIce': '4:07'}}},
#     'ID8475188': {'person': {'id': 8475188,
#       'fullName': 'Brayden McNabb',
#       'link': '/api/v1/people/8475188',
#       'firstName': 'Brayden',
#       'lastName': 'McNabb',
#       'primaryNumber': '3',
#       'birthDate': '1991-01-21',
#       'currentAge': 31,
#       'birthCity': 'Davidson',
#       'birthStateProvince': 'SK',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 4"',
#       'weight': 215,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '3',
#      'position': {'code': 'D',
#       'name': 'Defenseman',
#       'type': 'Defenseman',
#       'abbreviation': 'D'},
#      'stats': {'skaterStats': {'timeOnIce': '21:13',
#        'assists': 0,
#        'goals': 0,
#        'shots': 0,
#        'hits': 2,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 2,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 1,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 3,
#        'plusMinus': -1,
#        'evenTimeOnIce': '17:21',
#        'powerPlayTimeOnIce': '0:00',
#        'shortHandedTimeOnIce': '3:52'}}},
#     'ID8480007': {'person': {'id': 8480007,
#       'fullName': 'Jonas Rondbjerg',
#       'link': '/api/v1/people/8480007',
#       'firstName': 'Jonas',
#       'lastName': 'Rondbjerg',
#       'primaryNumber': '46',
#       'birthDate': '1999-03-31',
#       'currentAge': 23,
#       'birthCity': 'Horsholm',
#       'birthCountry': 'DNK',
#       'nationality': 'DNK',
#       'height': '6\' 2"',
#       'weight': 203,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'N',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'R',
#        'name': 'Right Wing',
#        'type': 'Forward',
#        'abbreviation': 'RW'}},
#      'jerseyNumber': '46',
#      'position': {'code': 'R',
#       'name': 'Right Wing',
#       'type': 'Forward',
#       'abbreviation': 'RW'},
#      'stats': {'skaterStats': {'timeOnIce': '7:54',
#        'assists': 0,
#        'goals': 0,
#        'shots': 0,
#        'hits': 0,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 2,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': -1,
#        'evenTimeOnIce': '7:27',
#        'powerPlayTimeOnIce': '0:00',
#        'shortHandedTimeOnIce': '0:27'}}},
#     'ID8478434': {'person': {'id': 8478434,
#       'fullName': 'Keegan Kolesar',
#       'link': '/api/v1/people/8478434',
#       'firstName': 'Keegan',
#       'lastName': 'Kolesar',
#       'primaryNumber': '55',
#       'birthDate': '1997-04-08',
#       'currentAge': 25,
#       'birthCity': 'Brandon',
#       'birthStateProvince': 'MB',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 2"',
#       'weight': 217,
#       'active': True,
#       'alternateCaptain': False,
# ...
#      'stats': {}},
#     'ID8477478': {'person': {'id': 8477478,
#       'fullName': 'William Carrier',
#       'link': '/api/v1/people/8477478',
#       'firstName': 'William',
#       'lastName': 'Carrier',
#       'primaryNumber': '28',
#       'birthDate': '1994-12-20',
#       'currentAge': 27,
#       'birthCity': 'LaSalle',
#       'birthStateProvince': 'QC',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 2"',
#       'weight': 218,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'L',
#        'name': 'Left Wing',
#        'type': 'Forward',
#        'abbreviation': 'LW'}},
#      'jerseyNumber': '28',
#      'position': {'code': 'L',
#       'name': 'Left Wing',
#       'type': 'Forward',
#       'abbreviation': 'LW'},
#      'stats': {'skaterStats': {'timeOnIce': '14:18',
#        'assists': 0,
#        'goals': 0,
#        'shots': 2,
#        'hits': 3,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 1,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 1,
#        'plusMinus': 0,
#        'evenTimeOnIce': '13:36',
#        'powerPlayTimeOnIce': '0:00',
#        'shortHandedTimeOnIce': '0:42'}}},
#     'ID8480727': {'person': {'id': 8480727,
#       'fullName': 'Zach Whitecloud',
#       'link': '/api/v1/people/8480727',
#       'firstName': 'Zach',
#       'lastName': 'Whitecloud',
#       'primaryNumber': '2',
#       'birthDate': '1996-11-28',
#       'currentAge': 26,
#       'birthCity': 'Brandon',
#       'birthStateProvince': 'MB',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 2"',
#       'weight': 207,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '2',
#      'position': {'code': 'D',
#       'name': 'Defenseman',
#       'type': 'Defenseman',
#       'abbreviation': 'D'},
#      'stats': {'skaterStats': {'timeOnIce': '22:05',
#        'assists': 0,
#        'goals': 0,
#        'shots': 1,
#        'hits': 2,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 3,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 2,
#        'plusMinus': -2,
#        'evenTimeOnIce': '16:49',
#        'powerPlayTimeOnIce': '0:02',
#        'shortHandedTimeOnIce': '5:14'}}},
#     'ID8478462': {'person': {'id': 8478462,
#       'fullName': 'Nicolas Roy',
#       'link': '/api/v1/people/8478462',
#       'firstName': 'Nicolas',
#       'lastName': 'Roy',
#       'primaryNumber': '10',
#       'birthDate': '1997-02-05',
#       'currentAge': 25,
#       'birthCity': 'Amos',
#       'birthStateProvince': 'QC',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 4"',
#       'weight': 202,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '10',
#      'position': {'code': 'C',
#       'name': 'Center',
#       'type': 'Forward',
#       'abbreviation': 'C'},
#      'stats': {'skaterStats': {'timeOnIce': '18:40',
#        'assists': 0,
#        'goals': 0,
#        'shots': 3,
#        'hits': 2,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffPct': 69.23,
#        'faceOffWins': 9,
#        'faceoffTaken': 13,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 1,
#        'plusMinus': -1,
#        'evenTimeOnIce': '15:49',
#        'powerPlayTimeOnIce': '1:41',
#        'shortHandedTimeOnIce': '1:10'}}},
#     'ID8479980': {'person': {'id': 8479980,
#       'fullName': 'Nicolas Hague',
#       'link': '/api/v1/people/8479980',
#       'firstName': 'Nicolas',
#       'lastName': 'Hague',
#       'primaryNumber': '14',
#       'birthDate': '1998-12-05',
#       'currentAge': 24,
#       'birthCity': 'Kitchener',
#       'birthStateProvince': 'ON',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 6"',
#       'weight': 230,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '14',
#      'position': {'code': 'D',
#       'name': 'Defenseman',
#       'type': 'Defenseman',
#       'abbreviation': 'D'},
#      'stats': {'skaterStats': {'timeOnIce': '17:54',
#        'assists': 0,
#        'goals': 0,
#        'shots': 0,
#        'hits': 1,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 1,
#        'plusMinus': 0,
#        'evenTimeOnIce': '16:13',
#        'powerPlayTimeOnIce': '0:00',
#        'shortHandedTimeOnIce': '1:41'}}},
#     'ID8479991': {'person': {'id': 8479991,
#       'fullName': 'Jake Leschyshyn',
#       'link': '/api/v1/people/8479991',
#       'firstName': 'Jake',
#       'lastName': 'Leschyshyn',
#       'primaryNumber': '15',
#       'birthDate': '1999-03-10',
#       'currentAge': 23,
#       'birthCity': 'Raleigh',
#       'birthStateProvince': 'NC',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '5\' 11"',
#       'weight': 195,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '15',
#      'position': {'code': 'C',
#       'name': 'Center',
#       'type': 'Forward',
#       'abbreviation': 'C'},
#      'stats': {'skaterStats': {'timeOnIce': '7:22',
#        'assists': 0,
#        'goals': 0,
#        'shots': 1,
#        'hits': 1,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffPct': 28.57,
#        'faceOffWins': 2,
#        'faceoffTaken': 7,
#        'takeaways': 0,
#        'giveaways': 0,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': 0,
#        'evenTimeOnIce': '6:55',
#        'powerPlayTimeOnIce': '0:00',
#        'shortHandedTimeOnIce': '0:27'}}},
#     'ID8474166': {'person': {'id': 8474166,
#       'fullName': 'Alec Martinez',
#       'link': '/api/v1/people/8474166',
#       'firstName': 'Alec',
#       'lastName': 'Martinez',
#       'primaryNumber': '23',
#       'birthDate': '1987-07-26',
#       'currentAge': 35,
#       'birthCity': 'Rochester Hills',
#       'birthStateProvince': 'MI',
#       'birthCountry': 'USA',
#       'nationality': 'USA',
#       'height': '6\' 1"',
#       'weight': 210,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '23',
#      'position': {'code': 'D',
#       'name': 'Defenseman',
#       'type': 'Defenseman',
#       'abbreviation': 'D'},
#      'stats': {'skaterStats': {'timeOnIce': '19:35',
#        'assists': 0,
#        'goals': 0,
#        'shots': 0,
#        'hits': 0,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 1,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 3,
#        'plusMinus': -2,
#        'evenTimeOnIce': '16:57',
#        'powerPlayTimeOnIce': '0:20',
#        'shortHandedTimeOnIce': '2:18'}}},
#     'ID8475191': {'person': {'id': 8475191,
#       'fullName': 'Reilly Smith',
#       'link': '/api/v1/people/8475191',
#       'firstName': 'Reilly',
#       'lastName': 'Smith',
#       'primaryNumber': '19',
#       'birthDate': '1991-04-01',
#       'currentAge': 31,
#       'birthCity': 'Mimico',
#       'birthStateProvince': 'ON',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 1"',
#       'weight': 185,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'L',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'R',
#        'name': 'Right Wing',
#        'type': 'Forward',
#        'abbreviation': 'RW'}},
#      'jerseyNumber': '19',
#      'position': {'code': 'R',
#       'name': 'Right Wing',
#       'type': 'Forward',
#       'abbreviation': 'RW'},
#      'stats': {'skaterStats': {'timeOnIce': '18:30',
#        'assists': 0,
#        'goals': 0,
#        'shots': 1,
#        'hits': 0,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 1,
#        'giveaways': 2,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': -1,
#        'evenTimeOnIce': '12:37',
#        'powerPlayTimeOnIce': '1:49',
#        'shortHandedTimeOnIce': '4:04'}}},
#     'ID8478020': {'person': {'id': 8478020,
#       'fullName': 'Michael Amadio',
#       'link': '/api/v1/people/8478020',
#       'firstName': 'Michael',
#       'lastName': 'Amadio',
#       'primaryNumber': '22',
#       'birthDate': '1996-05-13',
#       'currentAge': 26,
#       'birthCity': 'Sault Ste. Marie',
#       'birthStateProvince': 'ON',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 1"',
#       'weight': 204,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': False,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'C',
#        'name': 'Center',
#        'type': 'Forward',
#        'abbreviation': 'C'}},
#      'jerseyNumber': '22',
#      'position': {'code': 'N/A',
#       'name': 'Unknown',
#       'type': 'Unknown',
#       'abbreviation': 'N/A'},
#      'stats': {}},
#     'ID8482624': {'person': {'id': 8482624,
#       'fullName': 'Daniil Miromanov',
#       'link': '/api/v1/people/8482624',
#       'firstName': 'Daniil',
#       'lastName': 'Miromanov',
#       'primaryNumber': '42',
#       'birthDate': '1997-07-11',
#       'currentAge': 25,
#       'birthCity': 'Moscow',
#       'birthCountry': 'RUS',
#       'nationality': 'RUS',
#       'height': '6\' 4"',
#       'weight': 200,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': True,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'D',
#        'name': 'Defenseman',
#        'type': 'Defenseman',
#        'abbreviation': 'D'}},
#      'jerseyNumber': '42',
#      'position': {'code': 'D',
#       'name': 'Defenseman',
#       'type': 'Defenseman',
#       'abbreviation': 'D'},
#      'stats': {'skaterStats': {'timeOnIce': '16:29',
#        'assists': 0,
#        'goals': 0,
#        'shots': 1,
#        'hits': 0,
#        'powerPlayGoals': 0,
#        'powerPlayAssists': 0,
#        'penaltyMinutes': 0,
#        'faceOffWins': 0,
#        'faceoffTaken': 0,
#        'takeaways': 0,
#        'giveaways': 1,
#        'shortHandedGoals': 0,
#        'shortHandedAssists': 0,
#        'blocked': 0,
#        'plusMinus': 0,
#        'evenTimeOnIce': '15:43',
#        'powerPlayTimeOnIce': '0:00',
#        'shortHandedTimeOnIce': '0:46'}}},
#     'ID8480313': {'person': {'id': 8480313,
#       'fullName': 'Logan Thompson',
#       'link': '/api/v1/people/8480313',
#       'firstName': 'Logan',
#       'lastName': 'Thompson',
#       'primaryNumber': '36',
#       'birthDate': '1997-02-25',
#       'currentAge': 25,
#       'birthCity': 'Calgary',
#       'birthStateProvince': 'AB',
#       'birthCountry': 'CAN',
#       'nationality': 'CAN',
#       'height': '6\' 4"',
#       'weight': 205,
#       'active': True,
#       'alternateCaptain': False,
#       'captain': False,
#       'rookie': True,
#       'shootsCatches': 'R',
#       'rosterStatus': 'Y',
#       'currentTeam': {'id': 54,
#        'name': 'Vegas Golden Knights',
#        'link': '/api/v1/teams/54'},
#       'primaryPosition': {'code': 'G',
#        'name': 'Goalie',
#        'type': 'Goalie',
#        'abbreviation': 'G'}},
#      'jerseyNumber': '36',
#      'position': {'code': 'G',
#       'name': 'Goalie',
#       'type': 'Goalie',
#       'abbreviation': 'G'},
#      'stats': {'goalieStats': {'timeOnIce': '60:00',
#        'assists': 0,
#        'goals': 0,
#        'pim': 0,
#        'shots': 37,
#        'saves': 32,
#        'powerPlaySaves': 10,
#        'shortHandedSaves': 0,
#        'evenSaves': 22,
#        'shortHandedShotsAgainst': 0,
#        'evenShotsAgainst': 25,
#        'powerPlayShotsAgainst': 12,
#        'decision': 'L',
#        'savePercentage': 86.48648648648648,
#        'powerPlaySavePercentage': 83.33333333333334,
#        'evenStrengthSavePercentage': 88.0}}}},
#    'goalies': [8480313],
#    'skaters': [8480727,
#     8475188,
#     8473548,
#     8478462,
#     8479980,
#     8479991,
#     8475191,
#     8476905,
#     8474166,
#     8477447,
#     8477478,
#     8482624,
#     8481032,
#     8480007,
#     8478434,
#     8475913,
#     8476448,
#     8476539,
#     8478403,
#     8477018,
#     8478020],
#    'onIce': [8474166, 8475191, 8476448, 8478434, 8480313, 8480727],
#    'onIcePlus': [{'playerId': 8474166, 'shiftDuration': 73, 'stamina': 33},
#     {'playerId': 8475191, 'shiftDuration': 19, 'stamina': 100},
#     {'playerId': 8476448, 'shiftDuration': 65, 'stamina': 33},
#     {'playerId': 8478434, 'shiftDuration': 72, 'stamina': 33},
#     {'playerId': 8480313, 'shiftDuration': 232, 'stamina': 33},
#     {'playerId': 8480727, 'shiftDuration': 74, 'stamina': 33}],
#    'scratches': [8478403, 8477018, 8478020],
#    'penaltyBox': [],
#    'coaches': [{'person': {'fullName': 'Bruce Cassidy',
#       'link': '/api/v1/people/null'},
#      'position': {'code': 'HC',
#       'name': 'Head Coach',
#       'type': 'Head Coach',
#       'abbreviation': 'Head Coach'}}]}},
#  'officials': [{'official': {'id': 2294,
#     'fullName': 'Chris Rooney',
#     'link': '/api/v1/people/2294'},
#    'officialType': 'Referee'},
#   {'official': {'id': 4604,
#     'fullName': 'Jean Hebert',
#     'link': '/api/v1/people/4604'},
#    'officialType': 'Referee'},
#   {'official': {'id': 2329,
#     'fullName': 'Steve Barton',
#     'link': '/api/v1/people/2329'},
#    'officialType': 'Linesman'},
#   {'official': {'id': 7672,
#     'fullName': 'Travis Toomey',
#     'link': '/api/v1/people/7672'},
#    'officialType': 'Linesman'}]}

# %% [markdown]
# ### Play by Play

# %%
#res = engine.execute("DROP TABLE IF EXISTS nhl_play")
#res.close()

# %%
n_games = game_pks.shape[0]
for i, g in enumerate(game_pks['game_pk'].values):
    d = process_game(g)

    if d is not None:
        d['game_pk'] = g
        d.to_sql('nhl_play', engine, index = False, if_exists = 'append')
        
    if i % 20 == 0:
        print(i / n_games)
# Out:
# 0.0
